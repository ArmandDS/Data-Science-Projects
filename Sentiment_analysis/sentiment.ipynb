# %% [markdown]
# # Lab assignment: analyzing movie reviews with Recurrent Neural Networks

# %% [markdown]
# <img src="img/cinemaReviews.png" style="width:600px;">

# %% [markdown]
# In this assignment we will analyze the sentiment, positive or negative, expressed in a set of movie reviews IMDB. To do so we will make use of word embeddings and recurrent neural networks.

# %% [markdown]
# ## Guidelines

# %% [markdown]
# Throughout this notebook you will find empty cells that you will need to fill with your own code. Follow the instructions in the notebook and pay special attention to the following symbols.
#
# <table>
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td style="text-align:left">You will need to solve a question by writing your own code or answer in the cell immediately below, or in a different file as instructed.</td></tr>
#  <tr><td width="80"><img src="img/exclamation.png" style="width:auto;height:auto"></td><td style="text-align:left">This is a hint or useful observation that can help you solve this assignment. You are not expected to write any solution, but you should pay attention to them to understand the assignment.</td></tr>
#  <tr><td width="80"><img src="img/pro.png" style="width:auto;height:auto"></td><td style="text-align:left">This is an advanced and voluntary exercise that can help you gain a deeper knowledge into the topic. Good luck!</td></tr>
# </table>
#
# During the assigment you will make use of several Python packages that might not be installed in your machine. If that is the case, you can install new Python packages with
#
#     conda install PACKAGENAME
#
# if you are using Python Anaconda. Else you should use
#
#     pip install PACKAGENAME
#
# You will need the following packages for this particular assignment. Make sure they are available before proceeding:
#
# * **numpy**
# * **keras**
# * **matplotlib**

# %% [markdown]
# The following code will embed any plots into the notebook instead of generating a new window:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Lastly, if you need any help on the usage of a Python function you can place the writing cursor over its name and press Caps+Shift to produce a pop-out with related documentation. This will only work inside code cells.
#
# Let's go!

# %% [markdown]
# ## The Keras library

# %% [markdown]
# In this lab we will make use of the <a href=http://keras.io/>keras</a> Deep Learning library for Python. This library allows building several kinds of shallow and deep networks, following either a sequential or a graph architecture.

# %% [markdown]
# ## Data loading

# %% [markdown]
# We will make use of a part of the IMDB database on movie reviews. IMDB rates movies with a score ranging 0-10, but for simplicity we will consider a dataset of good and bad reviews, where a review has been considered bad with a score smaller than 4, and good if it features a score larger than 7. The data is available under the *data* folder.

# %% [markdown]
# <table>
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td style="text-align:left">
# Load the data into two variables, a list **text** with each of the movie reviews and a list **y** of the class labels.
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
import pandas as pd
#data = pd.read_csv("./data/datafull.csv", sep='\t')
data = pd.read_csv("./data/data.csv", sep='\t')
texts = data["text"]
y = data["sentiment"].values

# %% [markdown]
# For convenience in what follows we will also split the data into a training and test subsets.

# %% [markdown]
# <table>
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td style="text-align:left">
# Split the list of texts into **texts_train** and **texts_test** lists, keeping 25% of the texts for test. Split in the same way the labels, obtaining lists **y_train** and **y_test**.
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
from sklearn.model_selection import train_test_split
texts_train, texts_test, y_train, y_test = train_test_split(texts, y, stratify=y)

# %% [markdown]
# ## Data processing

# %% [markdown]
# We can't introduce text directly into the network, so we will have to tranform it to a vector representation. To do so, we will first **tokenize** the text into words (or tokens), and assign a unique identifier to each word found in the text. Doing this will allow us to perform the encoding. We can do this easily by making use of the **Tokenizer** class in keras:

# %%
from keras.preprocessing.text import Tokenizer
# Out:
# Using TensorFlow backend.

# %% [markdown]
# A Tokenizer offers convenient methods to split texts down to tokens. At construction time we need to supply the Tokenizer the maximum number of different words we are willing to represent. If out texts have greater word variety than this number, the least frequent words will be discarded. We will choose a number large enough for our purpose.

# %%
maxwords = 1000
tokenizer = Tokenizer(num_words = maxwords)

# %% [markdown]
# We now need to **fit** the Tokenizer to the training texts.

# %% [markdown]
# <table>
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td style="text-align:left">
# Find in the keras documentation the appropriate Tokenizer method to fit the tokenizer on a list of text, then use it to fit it on the training data.
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
tokenizer.fit_on_texts(texts_train)

# %% [markdown]
# If done correctly, the following should show the number of times the tokenizer has found each word in the input texts.

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('of', 11163),
#              ('life', 491),
#              ('in', 7015),
#              ('some', 1249),
#              ('colleges', 3),
#              ('course', 215),
#              ('there', 1211),
#              ('were', 798),
#              ('artistic', 39),
#              ('licenses', 1),
#              ('taken', 88),
#              ('but', 3267),
#              ('what', 1163),
#              ('you', 2289),
#              ('saw', 251),
#              ('this', 5849),
#              ('film', 2998),
#              ('go', 417),
#              ('on', 2554),
#              ('br', 8026),
#              ('i', 5840),
#              ('went', 101),
#              ('to', 10573),
#              ('southern', 10),
#              ('california', 23),
#              ('where', 480),
#              ('the', 25672),
#              ('races', 7),
#              ('pretty', 255),
#              ('much', 715),
#              ('hang', 14),
#              ('around', 306),
#              ('with', 3297),
#              ('their', 815),
#              ('own', 254),
#              ("it's", 1267),
#              ('funny', 308),
#              ('because', 685),
#              ('these', 419),
#              ('are', 2254),
#              ('schools', 4),
#              ('that', 5289),
#              ('want', 253),
#              ('racial', 4),
#              ('unity', 3),
#              ('equality', 2),
#              ('etc', 82),
#              ('and', 12263),
#              ('can', 849),
#              ('honestly', 29),
#              ('say', 395),
#              ('thing', 321),
#              ('is', 8362),
#              ('when', 1096),
#              ('class', 77),
#              ('lets', 26),
#              ('out', 1406),
#              ('or', 1427),
#              ("they're", 97),
#              ('just', 1345),
#              ('hanging', 15),
#              ('waiting', 45),
#              ('for', 3369),
#              ('they', 1576),
#              ('students', 33),
#              ('seem', 129),
#              ('people', 699),
#              ('race', 34),
#              ('ethnicity', 2),
#              ('bad', 717),
#              ('not', 2235),
#              ('really', 901),
#              ('everyone', 172),
#              ('needs', 61),
#              ('a', 12341),
#              ('feeling', 85),
#              ('belonging', 3),
#              ('like', 1604),
#              ('school', 81),
#              ('paper', 18),
#              ('one', 2000),
#              ('attended', 7),
#              ('once', 192),
#              ('wrote', 41),
#              ('about', 1368),
#              ('we', 772),
#              ('should', 398),
#              ('all', 1722),
#              ('try', 150),
#              ('other', 670),
#              ('ethnicities', 2),
#              ('know', 483),
#              ('them', 556),
#              ('otherwise', 55),
#              ("you're", 149),
#              ('creating', 27),
#              ('your', 401),
#              ('segregation', 2),
#              ('racism', 14),
#              ('certainly', 112),
#              ('existed', 8),
#              ('those', 386),
#              ('time', 978),
#              ('someone', 162),
#              ('put', 169),
#              ('leaflets', 1),
#              ('campus', 10),
#              ('talking', 68),
#              ('glories', 1),
#              ('aryan', 1),
#              ('had', 813),
#              ('symbols', 3),
#              ('racist', 15),
#              ('organizations', 2),
#              ('fortunately', 17),
#              ('nothing', 378),
#              ('happened', 67),
#              ('incident', 7),
#              ('movie', 3192),
#              ('young', 277),
#              ('caucasian', 3),
#              ('man', 439),
#              ('off', 452),
#              ('started', 85),
#              ('shooting', 36),
#              ('at', 1751),
#              ('multiculturalism', 1),
#              ('gathering', 5),
#              ('only', 888),
#              ('hope', 113),
#              ('pray', 4),
#              ('ever', 445),
#              ('will', 665),
#              ('happen', 89),
#              ('so', 1492),
#              ('higher', 24),
#              ('learning', 10),
#              ('overly', 21),
#              ('dramatic', 55),
#              ('exaggerated', 12),
#              ('maybe', 186),
#              ('it', 6095),
#              ('way', 642),
#              ('mark', 65),
#              ('depends', 6),
#              ('does', 456),
#              ('minus', 8),
#              ('hollywood', 144),
#              ('exaggerations', 2),
#              ('hit', 76),
#              ('close', 94),
#              ('home', 151),
#              ('me', 777),
#              ('an', 1611),
#              ('early', 131),
#              ('pilot', 27),
#              ('canadian', 24),
#              ('tv', 248),
#              ('show', 542),
#              ('trailer', 33),
#              ('park', 33),
#              ('boys', 54),
#              ('was', 3536),
#              ('played', 192),
#              ('executives', 7),
#              ('few', 341),
#              ('networks', 7),
#              ('before', 335),
#              ('showcase', 8),
#              ('decided', 53),
#              ('sign', 26),
#              ('up', 1003),
#              ('series', 282),
#              ('great', 695),
#              ('acting', 483),
#              ('very', 1076),
#              ('cast', 275),
#              ('make', 660),
#              ('best', 513),
#              ('cult', 22),
#              ('comedy', 235),
#              ('films', 550),
#              ('plot', 473),
#              ('two', 549),
#              ('small', 128),
#              ('criminals', 12),
#              ('exterminating', 1),
#              ('peoples', 6),
#              ('pets', 3),
#              ('money', 196),
#              ('if', 1218),
#              ('have', 2040),
#              ('dog', 73),
#              ('next', 138),
#              ('door', 35),
#              ('whos', 3),
#              ('barking', 2),
#              ('night', 150),
#              ('guys', 102),
#              ('get', 714),
#              ('into', 651),
#              ('trouble', 47),
#              ('come', 257),
#              ('across', 61),
#              ('job', 164),
#              ('too', 578),
#              ('big', 250),
#              ('deal', 60),
#              ('end', 417),
#              ('shootout', 3),
#              ('watch', 524),
#              ('understand', 115),
#              ('beginning', 103),
#              ('highly', 83),
#              ('recommend', 125),
#              ('rated', 43),
#              ('r', 36),
#              ('swearing', 5),
#              ('violence', 88),
#              ('drug', 27),
#              ('use', 135),
#              ('its', 654),
#              ('offensive', 20),
#              ('either', 139),
#              ('dont', 5),
#              ('actually', 274),
#              ('killing', 54),
#              ('animals', 25),
#              ('lot', 284),
#              ('obvious', 79),
#              ('hype', 10),
#              ('associated', 12),
#              ("let's", 56),
#              ('face', 110),
#              ('though', 363),
#              ('main', 177),
#              ('reasons', 60),
#              ('why', 443),
#              ('anyone', 176),
#              ('would', 959),
#              ('be', 2060),
#              ('leo', 24),
#              ('cate', 1),
#              ('who', 1586),
#              ('necessarily', 23),
#              ('actors', 327),
#              ("i'm", 361),
#              ('saying', 80),
#              ('good', 1112),
#              ('stunk', 2),
#              ('special', 156),
#              ('effects', 171),
#              ('decent', 71),
#              ('makers', 36),
#              ('did', 440),
#              ('making', 217),
#              ('ship', 14),
#              ('eye', 65),
#              ('pleasing', 8),
#              ('even', 959),
#              ('has', 1429),
#              ('several', 110),
#              ('major', 60),
#              ('flaws', 29),
#              ('instance', 32),
#              ('right', 246),
#              ('goes', 192),
#              ('under', 94),
#              ('see', 898),
#              ('unfinished', 3),
#              ('blue', 33),
#              ('screen', 190),
#              ('image', 30),
#              ('behind', 111),
#              ('characters', 539),
#              ("don't", 676),
#              ('wrong', 138),
#              ('love', 465),
#              ('story', 890),
#              ('real', 363),
#              ('titanic', 10),
#              ('find', 304),
#              ('insult', 17),
#              ('editing', 45),
#              ('atrocious', 12),
#              ("there's", 258),
#              ('no', 953),
#              ('reason', 189),
#              ('any', 550),
#              ('over', 474),
#              ('2', 197),
#              ('1', 167),
#              ('hours', 71),
#              ('exception', 33),
#              ('biographical', 1),
#              ('writing', 93),
#              ('screenplay', 55),
#              ('horribly', 21),
#              ('stilted', 6),
#              ('music', 236),
#              ('perhaps', 140),
#              ('better', 394),
#              ('than', 712),
#              ('could', 563),
#              ('predicted', 2),
#              ('my', 957),
#              ('heart', 87),
#              ('song', 76),
#              ('scene', 381),
#              ('stands', 32),
#              ('sinking', 6),
#              ('pounding', 3),
#              ('bass', 1),
#              ('heard', 73),
#              ('well', 839),
#              ('highlight', 18),
#              ('as', 3563),
#              ('mood', 36),
#              ('throughout', 111),
#              ('extremely', 93),
#              ('dull', 76),
#              ('more', 1115),
#              ('relieved', 2),
#              ('sad', 67),
#              ('jack', 44),
#              ('died', 41),
#              ('which', 966),
#              ('cannot', 66),
#              ('director', 340),
#              ('intended', 33),
#              ('nut', 6),
#              ('shell', 7),
#              ('horrible', 84),
#              ('turned', 76),
#              ('beautiful', 163),
#              ('hyped', 3),
#              ('chick', 25),
#              ('flick', 93),
#              ('somebody', 22),
#              ('mastered', 2),
#              ('difficult', 41),
#              ('task', 16),
#              ('merging', 1),
#              ('sports', 23),
#              ('romance', 49),
#              ('reality', 89),
#              ('together', 190),
#              ('oil', 10),
#              ('water', 41),
#              ('successfully', 5),
#              ('equivalent', 5),
#              ('splitting', 2),
#              ('atom', 2),
#              ('never', 514),
#              ('thought', 239),
#              ('done', 228),
#              ('first', 685),
#              ('general', 59),
#              ('romantic', 58),
#              ('comedies', 43),
#              ('do', 683),
#              ('most', 661),
#              ('movies', 530),
#              ('mix', 24),
#              ('being', 506),
#              ('baseball', 11),
#              ('fan', 146),
#              ('appreciate', 37),
#              ('comedic', 29),
#              ('ordeal', 6),
#              ('ben', 53),
#              ('wrightman', 1),
#              ('jimmy', 22),
#              ('falon', 1),
#              ('rabid', 3),
#              ('boston', 7),
#              ('redsox', 3),
#              ('knows', 80),
#              ('anything', 200),
#              ('curse', 18),
#              ('babe', 7),
#              ('plagued', 3),
#              ('86', 1),
#              ('years', 334),
#              ('how', 665),
#              ('nuts', 11),
#              ('fans', 96),
#              ('farrely', 1),
#              ('brothers', 47),
#              ('capturing', 6),
#              ('made', 632),
#              ('appeal', 30),
#              ('many', 465),
#              ('rented', 26),
#              ('interest', 74),
#              ('american', 141),
#              ('history', 99),
#              ('especially', 185),
#              ('somewhat', 65),
#              ('weird', 46),
#              ('mormons', 5),
#              ('attempts', 47),
#              ('sense', 192),
#              ('joseph', 17),
#              ('smith', 52),
#              ('turn', 120),
#              ('his', 2198),
#              ('vision', 19),
#              ('world', 278),
#              ('religion', 12),
#              ('focuses', 12),
#              ('troubles', 2),
#              ('settlement', 1),
#              ('navuoo', 1),
#              ('illinois', 3),
#              ('portrays', 15),
#              ('trial', 15),
#              ('within', 57),
#              ('brigham', 1),
#              ('tell', 128),
#              ('conversion', 4),
#              ('mormonism', 2),
#              ('belief', 15),
#              ('spiritual', 14),
#              ('message', 67),
#              ('then', 564),
#              ('assassinated', 2),
#              ('must', 237),
#              ('doubts', 13),
#              ('whether', 66),
#              ('he', 2119),
#              ('been', 640),
#              ('chosen', 24),
#              ('lead', 82),
#              ('new', 288),
#              ('land', 19),
#              ('despite', 94),
#              ('grave', 7),
#              ('perseveres', 2),
#              ('finally', 141),
#              ('utah', 2),
#              ('place', 190),
#              ('colony', 6),
#              ('gives', 109),
#              ('him', 618),
#              ('confidence', 8),
#              ('rightness', 1),
#              ('leadership', 5),
#              ('later', 157),
#              ('crops', 2),
#              ('destroyed', 12),
#              ('by', 1705),
#              ('crickets', 1),
#              ('again', 312),
#              ('truly', 150),
#              ('however', 237),
#              ('miracle', 4),
#              ('occurs', 8),
#              ('cements', 1),
#              ('found', 202),
#              ('performances', 137),
#              ('moving', 72),
#              ('convincing', 37),
#              ('interesting', 242),
#              ('believe', 160),
#              ('accurate', 23),
#              ('portrayal', 39),
#              ('polygamy', 1),
#              ('part', 309),
#              ('central', 35),
#              ('lds', 8),
#              ('raised', 11),
#              ('issue', 23),
#              ('emphasized', 3),
#              ('sure', 219),
#              ('stay', 58),
#              ('away', 244),
#              ('from', 1575),
#              ('religious', 16),
#              ('subject', 53),
#              ('matter', 83),
#              ('hold', 36),
#              ("can't", 221),
#              ('tht', 1),
#              ('richard', 50),
#              ('roeper', 1),
#              ('roger', 12),
#              ('ebert', 4),
#              ('mr', 138),
#              ('carrey', 17),
#              ('makeup', 16),
#              ('am', 215),
#              ('actresses', 27),
#              ('taylor', 28),
#              ('momsen', 2),
#              ('plays', 163),
#              ('cindy', 5),
#              ('lou', 9),
#              ('opens', 24),
#              ('grinch', 11),
#              ('jim', 37),
#              ('comes', 186),
#              ('hiding', 7),
#              ('causes', 14),
#              ('mean', 119),
#              ('fun', 207),
#              ('whoville', 2),
#              ('sicne', 1),
#              ('christmas', 69),
#              ('while', 408),
#              ('makes', 305),
#              ('little', 448),
#              ('daughter', 63),
#              ("town's", 3),
#              ('postmaster', 1),
#              ('bill', 46),
#              ('irwin', 3),
#              ('directed', 90),
#              ('ron', 11),
#              ('howard', 32),
#              ("narrtor's", 1),
#              ('voice', 86),
#              ('anthony', 20),
#              ('hopkins', 3),
#              ('jeffrey', 6),
#              ('tambor', 3),
#              ('muppets', 3),
#              ('space', 63),
#              ('mayor', 7),
#              ("doesn't", 380),
#              ('back', 394),
#              ('imc6', 1),
#              ('san', 12),
#              ('jose', 1),
#              ('five', 69),
#              ('mind', 155),
#              ('three', 183),
#              ('us', 269),
#              ('hardcore', 7),
#              ('kamal', 10),
#              ('reached', 12),
#              ('unanimous', 2),
#              ('verdict', 4),
#              ('vv', 3),
#              ('solid', 43),
#              ('crap', 91),
#              ('thanks', 37),
#              ('going', 324),
#              ('screwed', 4),
#              ('monday', 4),
#              ('mention', 59),
#              ('swore', 1),
#              ('theatres', 6),
#              ('year', 167),
#              ("won't", 93),
#              ('blame', 15),
#              ('here', 392),
#              ('sort', 117),
#              ('dropped', 8),
#              ('hint', 17),
#              ('recent', 33),
#              ('interview', 14),
#              ('cartoonist', 1),
#              ('madan', 1),
#              ('vijay', 1),
#              ('said', 151),
#              ('something', 390),
#              ('tamizh', 1),
#              ("cinema'la", 1),
#              ('photography', 35),
#              ("editing'la", 1),
#              ('namba', 2),
#              ("munnera'na", 1),
#              ('maadri', 1),
#              ('direction', 120),
#              ("acting'la", 1),
#              ('innum', 1),
#              ("munnera'la", 1),
#              ('tamil', 1),
#              ('cinema', 112),
#              ('grown', 21),
#              ('terms', 35),
#              ('hardly', 55),
#              ('improved', 5),
#              ('watching', 389),
#              ('words', 70),
#              ('ring', 25),
#              ('true', 169),
#              ('now', 349),
#              ('10', 353),
#              ('hate', 43),
#              ('harris', 17),
#              ('jeyaraj', 3),
#              ('3', 138),
#              ('barely', 49),
#              ('holding', 19),
#              ('myself', 91),
#              ('using', 46),
#              ('expletives', 1),
#              ('fact', 279),
#              ('hj', 1),
#              ('fine', 101),
#              ('knack', 2),
#              ('screwing', 2),
#              ('every', 332),
#              ('remember', 140),
#              ("'anniyan'", 1),
#              ("'ghajini'", 1),
#              ('jarring', 5),
#              ('cacophony', 1),
#              ('bills', 6),
#              ('background', 56),
#              ('eardrum', 1),
#              ('transplant', 2),
#              ("he's", 227),
#              ('paying', 14),
#              ('4', 112),
#              ('songs', 77),
#              ('neither', 37),
#              ('help', 118),
#              ('move', 46),
#              ("movie's", 33),
#              ('narration', 13),
#              ('spatially', 1),
#              ('temporally', 1),
#              ('nor', 45),
#              ('sit', 57),
#              ('take', 275),
#              ('notice', 33),
#              ('feels', 62),
#              ('four', 58),
#              ('long', 275),
#              ('scenes', 388),
#              ('thrown', 29),
#              ('between', 278),
#              ('5', 119),
#              ('short', 158),
#              ('gone', 63),
#              ('far', 216),
#              ('fit', 36),
#              ('hour', 85),
#              ('plus', 47),
#              ('thriller', 92),
#              ('cliché', 20),
#              ('energizer', 1),
#              ('bunny', 3),
#              ('case', 103),
#              ('drag', 11),
#              ('6', 37),
#              ('jothika', 2),
#              ('pairing', 4),
#              ('ice', 15),
#              ('cubes', 1),
#              ('rubbed', 2),
#              ("could've", 14),
#              ('produced', 43),
#              ('sparks', 4),
#              ('root', 11),
#              ('second', 138),
#              ('half', 138),
#              ('irritant', 1),
#              ('kamalini', 1),
#              ("mukerjhee's", 1),
#              ('minute', 64),
#              ('romancing', 1),
#              ('achieve', 11),
#              ("'thenali'", 1),
#              ('7', 59),
#              ("haasan's", 1),
#              ('accent', 32),
#              ('pretentious', 21),
#              ('nobody', 25),
#              ('speaks', 16),
#              ('india', 11),
#              ("isn't", 262),
#              ('doing', 117),
#              ('since', 223),
#              ("'thoongadae", 1),
#              ('thambi', 1),
#              ("thoongadae'", 1),
#              ('simply', 124),
#              ('gets', 231),
#              ('nerve', 5),
#              ('imagine', 69),
#              ('havoc', 1),
#              ('cause', 33),
#              ('flair', 5),
#              ('strange', 85),
#              ('meets', 43),
#              ('location', 32),
#              ('leave', 85),
#              ('immigration', 2),
#              ('offers', 27),
#              ('doses', 1),
#              ('advice', 19),
#              ('men', 137),
#              ('bewildered', 1),
#              ('tn', 1),
#              ('cops', 22),
#              ('keeranor', 1),
#              ('sathoor', 1),
#              ('beyond', 62),
#              ('chaste', 1),
#              ('kamanglish', 1),
#              ('wha', 1),
#              ('hav', 1),
#              ('plain', 49),
#              ('police', 93),
#              ('wok', 1),
#              ('nauseating', 6),
#              ('effect', 44),
#              ('8', 65),
#              ('logic', 19),
#              ('directors', 41),
#              ('whom', 48),
#              ('expect', 92),
#              ('stand', 69),
#              ('certain', 53),
#              ('scale', 13),
#              ('gautam', 1),
#              ('fails', 46),
#              ('badly', 52),
#              ('crappy', 15),
#              ('performance', 201),
#              ('department', 12),
#              ('common', 44),
#              ('d', 45),
#              ('c', 49),
#              ('p', 30),
#              ('senses', 6),
#              ('meet', 62),
#              ('streets', 30),
#              ('discuss', 11),
#              ('such', 389),
#              ('matters', 19),
#              ('committing', 6),
#              ('himself', 152),
#              ('after', 570),
#              ('inside', 43),
#              ('theatre', 32),
#              ('towards', 41),
#              ('climax', 29),
#              ('hear', 63),
#              ('loudly', 2),
#              ('challenge', 12),
#              ("hero's", 5),
#              ('iq', 1),
#              ('stupid', 158),
#              ('siren', 1),
#              ('lights', 17),
#              ('busy', 11),
#              ('madras', 1),
#              ('road', 41),
#              ('cop', 56),
#              ('jeep', 3),
#              ('chases', 7),
#              ('guy', 265),
#              ('bike', 10),
#              ('ordinary', 13),
#              ('dude', 12),
#              ('gun', 47),
#              ('starts', 87),
#              ('foot', 18),
#              ('fully', 36),
#              ('geared', 3),
#              ('hot', 54),
#              ('pursuit', 10),
#              ('considerable', 5),
#              ('amount', 37),
#              ('voting', 4),
#              ('favour', 7),
#              ('trying', 175),
#              ('explain', 38),
#              ('9', 67),
#              ('gore', 65),
#              ('wanted', 104),
#              ('women', 136),
#              ('raped', 11),
#              ('throats', 4),
#              ('getting', 115),
#              ('slashed', 2),
#              ('bushes', 2),
#              ('excruciating', 5),
#              ('authenticity', 6),
#              ('rather', 186),
#              ('report', 6),
#              ('kuttram', 1),
#              ('excessive', 5),
#              ('extend', 2),
#              ('overwhelm', 1),
#              ('somewhere', 38),
#              ('down', 271),
#              ('line', 113),
#              ('gautum', 1),
#              ('seems', 271),
#              ('confused', 26),
#              ('extensions', 1),
#              ('rapes', 2),
#              ('murders', 21),
#              ('mainstay', 3),
#              ('double', 35),
#              ('shot', 156),
#              ('espresso', 1),
#              ("couldn't", 102),
#              ('pain', 25),
#              ('head', 101),
#              ('formula', 21),
#              ('wants', 100),
#              ('girl', 214),
#              ('lie', 15),
#              ('friend', 105),
#              ('outrageous', 14),
#              ('comedus', 1),
#              ('reliefus', 1),
#              ('deceive', 2),
#              ("one's", 22),
#              ('death', 150),
#              ('rare', 40),
#              ('z', 14),
#              ('outings', 8),
#              ('stale', 4),
#              ('aside', 27),
#              ('leads', 50),
#              ('attractive', 30),
#              ('couple', 133),
#              ('moments', 120),
#              ('jonathon', 1),
#              ('schaech', 2),
#              ('came', 102),
#              ('phoned', 2),
#              ('complete', 74),
#              ('loss', 15),
#              ('tepid', 5),
#              ('affair', 27),
#              ('touching', 29),
#              ('strong', 87),
#              ('without', 266),
#              ('question', 43),
#              ('breathless', 6),
#              ('work', 330),
#              ('team', 50),
#              ('feel', 217),
#              ('sorry', 57),
#              ('marlene', 7),
#              ('grace', 14),
#              ('god', 79),
#              ('friendship', 19),
#              ('kills', 34),
#              ('opinion', 69),
#              ('kind', 198),
#              ('heartbreaking', 3),
#              ('drama', 119),
#              ('consequences', 10),
#              ('anorexic', 3),
#              ('bulimic', 2),
#              ('anytime', 4),
#              ('lexi', 1),
#              ('katie', 1),
#              ('wright', 9),
#              ('jennifer', 15),
#              ('marley', 3),
#              ('shelton', 1),
#              ('threw', 8),
#              ('vomit', 6),
#              ('hard', 196),
#              ('ask', 58),
#              ('cooperative', 1),
#              ('things', 294),
#              ('enjoy', 132),
#              ('seeing', 150),
#              ('lectured', 1),
#              ('parents', 56),
#              ('wrap', 8),
#              ("i'd", 104),
#              ('indeed', 47),
#              ('affect', 6),
#              ("person's", 5),
#              ('body', 72),
#              ('conclusion', 36),
#              ("hasn't", 36),
#              ('seen', 518),
#              ('tears', 22),
#              ('kick', 12),
#              ('biggest', 33),
#              ('joke', 65),
#              ('bother', 37),
#              ('ff', 1),
#              ('20', 56),
#              ('min', 5),
#              ('disappointing', 27),
#              ('taste', 41),
#              ('horror', 258),
#              ('fastidious', 1),
#              ('limit', 3),
#              ('quarter', 7),
#              ('star', 145),
#              ('hoast', 2),
#              ("that's", 251),
#              ('waste', 110),
#              ('15', 46),
#              ('minutes', 222),
#              ("you'll", 102),
#              ('able', 93),
#              ('monkeys', 3),
#              ('brother', 86),
#              ('parental', 1),
#              ('role', 212),
#              ('awful', 129),
#              ('pay', 51),
#              ('think', 533),
#              ('absolutely', 102),
#              ('ten', 66),
#              ('charing', 1),
#              ('places', 28),
#              ('portrait', 12),
#              ('vampire', 30),
#              ('cabin', 19),
#              ('lake', 20),
#              ('ago', 81),
#              ('bought', 34),
#              ("dvd's", 6),
#              ('contained', 11),
#              ('each', 173),
#              ('broadway', 13),
#              ('girls', 89),
#              ('alternate', 5),
#              ('title', 114),
#              ('greeks', 4),
#              ('word', 73),
#              ('happy', 52),
#              ('lovely', 27),
#              ('basically', 73),
#              ('backstage', 1),
#              ('musical', 82),
#              ('takes', 194),
#              ('scotland', 4),
#              ('concerns', 12),
#              ('mistaken', 13),
#              ('identity', 25),
#              ('involving', 31),
#              ('dancers', 9),
#              ('hitching', 1),
#              ('ride', 23),
#              ("millionaire's", 1),
#              ('limousine', 1),
#              ('vera', 10),
#              ('ellen', 12),
#              ('dancer', 7),
#              ('wow', 30),
#              ('legs', 13),
#              ('ceasar', 1),
#              ('romero', 5),
#              ('her', 1366),
#              ('producer', 36),
#              ('chance', 88),
#              ('original', 253),
#              ('leading', 46),
#              ('lady', 71),
#              ('leaves', 56),
#              ('thinks', 28),
#              ("she's", 116),
#              ('dating', 7),
#              ('millionaire', 8),
#              ('whose', 77),
#              ('car', 81),
#              ('mentioned', 39),
#              ('david', 51),
#              ('niven', 6),
#              ('rich', 40),
#              ('looking', 194),
#              ('reporter', 10),
#              ("who's", 59),
#              ('supposed', 119),
#              ('stalled', 2),
#              ("i've", 230),
#              ('may', 229),
#              ('confusing', 25),
#              ('mostly', 71),
#              ('willing', 30),
#              ('check', 60),
#              ('brain', 26),
#              ('charmingly', 2),
#              ('screwball', 4),
#              ('wonderful', 122),
#              ('numbers', 29),
#              ('performed', 20),
#              ('exquisite', 6),
#              ('ms', 23),
#              ('bit', 230),
#              ('frantic', 3),
#              ('becomes', 111),
#              ('hilariously', 7),
#              ('bemused', 2),
#              ('print', 19),
#              ('considering', 44),
#              ('age', 85),
#              ('public', 44),
#              ('domain', 4),
#              ('lines', 103),
#              ('actress', 78),
#              ...])

# %% [markdown]
# Now we have trained the tokenizer we can use it to vectorize the texts. In particular, we would like to transform the texts to sequences of word indexes.

# %% [markdown]
# <table>
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td style="text-align:left">
# Find in the keras documentation the appropriate Tokenizer method to transform a list of texts to a sequence. Apply it to both the training and test data to obtain matrices **X_train** and **X_test**.
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
X_train = tokenizer.texts_to_sequences(texts_train)
X_test = tokenizer.texts_to_sequences(texts_test)

# %% [markdown]
# We can see now how a text has been transformed to a list of word indexes.

# %%
X_train[0]
# Out:
# [4,
#  112,
#  8,
#  45,
#  4,
#  238,
#  47,
#  69,
#  532,
#  17,
#  45,
#  4,
#  48,
#  21,
#  200,
#  8,
#  10,
#  19,
#  129,
#  20,
#  8,
#  45,
#  7,
#  7,
#  11,
#  472,
#  5,
#  8,
#  115,
#  1,
#  196,
#  73,
#  167,
#  16,
#  67,
#  197,
#  44,
#  165,
#  79,
#  128,
#  22,
#  12,
#  198,
#  576,
#  3,
#  11,
#  65,
#  134,
#  12,
#  44,
#  47,
#  17,
#  1,
#  162,
#  6,
#  51,
#  608,
#  40,
#  39,
#  51,
#  488,
#  43,
#  40,
#  15,
#  608,
#  35,
#  382,
#  5,
#  43,
#  167,
#  16,
#  76,
#  4,
#  67,
#  197,
#  39,
#  6,
#  12,
#  72,
#  23,
#  61,
#  289,
#  768,
#  2,
#  552,
#  4,
#  17,
#  33,
#  1,
#  579,
#  4,
#  28,
#  4,
#  1,
#  11,
#  259,
#  41,
#  12,
#  71,
#  133,
#  30,
#  320,
#  5,
#  167,
#  16,
#  4,
#  83,
#  3,
#  320,
#  5,
#  113,
#  98,
#  855,
#  326,
#  132,
#  197,
#  7,
#  7,
#  430,
#  8,
#  28,
#  4,
#  142,
#  11,
#  28,
#  54,
#  300,
#  291,
#  167,
#  689,
#  41,
#  1,
#  4,
#  1,
#  3,
#  68,
#  1,
#  4,
#  45,
#  4,
#  142,
#  145,
#  703,
#  33,
#  1,
#  8,
#  1,
#  18,
#  115,
#  1,
#  179,
#  127,
#  472,
#  121,
#  3,
#  553,
#  29,
#  2,
#  7,
#  7,
#  11,
#  65,
#  64,
#  427,
#  3,
#  12,
#  145,
#  33,
#  12,
#  123,
#  84,
#  527,
#  7,
#  7,
#  37,
#  6,
#  856,
#  272,
#  6,
#  9,
#  90,
#  121,
#  727,
#  9,
#  20,
#  115,
#  21,
#  472,
#  5,
#  39,
#  129,
#  5,
#  579,
#  1,
#  162,
#  115,
#  1,
#  43,
#  167,
#  16,
#  67,
#  197,
#  120,
#  527,
#  1,
#  335,
#  1,
#  162,
#  618,
#  196,
#  499,
#  5,
#  318,
#  15,
#  70]

# %% [markdown]
# This is enough to train a Sequential Network. However, for efficiency reasons it is recommended that all sequences in the data have the same number of elements. Since this is not the case for our data, should **pad** the sequences to ensure the same length. The padding procedure adds a special *null* symbol to short sequences, and clips out parts of long sequences, thus enforcing a common size.

# %% [markdown]
# <table>
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td style="text-align:left">
#
# Find in the keras documentation the appropriate text preprocessing method to pad a sequence. Then pad all sequences to have a maximum of 300 words, both in the training and test data.
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
from keras.preprocessing.sequence import pad_sequences 
maxsequence = 300
X_train = pad_sequences(X_train, maxlen=maxsequence)
X_test = pad_sequences(X_test, maxlen=maxsequence)

# %% [markdown]
# ## Simple LSTM network with Embedding

# %% [markdown]
# To transform the word indices into something more amenable for a network we will use an <a href=https://keras.io/layers/embeddings/>**Embedding**</a> layer at the very beginning of the network. This layer will transform word indexes to a vector representation that is learned with the model together with the rest of network weights. After this transformation we will make use of an <a href=https://keras.io/layers/recurrent/#lstm>**LSTM**</a> layer to analyze the whole sequence, and then a final layer taking the decision of the network.

# %% [markdown]
# <table>
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td style="text-align:left">
# Build, compile and train a keras network with the following structure:
# <ul>
#  <li>Embedding layer producing a vector representation of 64 elements</li>
#  <li>LSTM layer of 32 units</li>
#  <li>Dropout of 0.9</li>
#  <li>Dense layer of 1 unit with sigmoid activation</li>
# </ul>
# Note that the Embedding layer requires specifing as first argument the maximum number of words we chose to for the tokenizer. Also, the LSTM layer requires setting the **input_shape** parameter as a tuple including the number of elements in the input sequences.
# Use the binary crossentropy loss function for training, together with the adam optimizer. Train for 10 epochs. After training, measure the accuracy on the test set.
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM
from keras.models import Sequential

model = Sequential()
model.add(Embedding(maxwords, 64))
model.add(LSTM(32, input_shape=(maxsequence,)))
model.add(Dropout(0.9))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=["accuracy"])
model.summary()

model.fit(X_train, y_train, batch_size=64, epochs=10, validation_data=(X_test, y_test))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 64)          64000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 76,449
# Trainable params: 76,449
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1875 samples, validate on 625 samples
# Epoch 1/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.6915 - acc: 0.5248 - val_loss: 0.6892 - val_acc: 0.6128
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.6839 - acc: 0.6000 - val_loss: 0.6798 - val_acc: 0.6432
# Epoch 3/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.6411 - acc: 0.6832 - val_loss: 0.6075 - val_acc: 0.7424
# Epoch 4/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.5305 - acc: 0.7797 - val_loss: 0.4755 - val_acc: 0.7680
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4348 - acc: 0.8288 - val_loss: 0.4672 - val_acc: 0.7856
# Epoch 6/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.3634 - acc: 0.8709 - val_loss: 0.4520 - val_acc: 0.8048
# Epoch 7/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3390 - acc: 0.8917 - val_loss: 0.4587 - val_acc: 0.8016
# Epoch 8/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3142 - acc: 0.8896 - val_loss: 0.5551 - val_acc: 0.7888
# Epoch 9/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2915 - acc: 0.9109 - val_loss: 0.4710 - val_acc: 0.7872
# Epoch 10/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2586 - acc: 0.9221 - val_loss: 0.5114 - val_acc: 0.7728

# %% [markdown]
# ## Stacked LSTMs

# %% [markdown]
# Much like other neural layers, LSTM layers can be stacked on top of each other to produce more complex models. Care must be taken, however, that the LSTM layers before the last one generate a whole sequence of outputs for the following LSTM to process.

# %% [markdown]
# <table>
#  <tr><td width="80"><img src="img/question.png" style="width:auto;height:auto"></td><td style="text-align:left">
# Repeat the training of the previous network, but using 2 LSTM layers. Make sure to configure the first LSTM layer in a way that it outputs a whole sequence for the next layer.
#  </td></tr>
# </table>

# %%
####### INSERT YOUR CODE HERE
from keras.layers.embeddings import Embedding

model = Sequential()
model.add(Embedding(maxwords, 64))
model.add(LSTM(32, input_shape=(maxsequence,), return_sequences=True))
model.add(Dropout(0.9))
model.add(LSTM(32, input_shape=(maxsequence,)))
model.add(Dropout(0.9))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=["accuracy"])
model.summary()

model.fit(X_train, y_train, batch_size=64, epochs=10, validation_data=(X_test, y_test))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, None, 64)          64000
# _________________________________________________________________
# lstm_2 (LSTM)                (None, None, 32)          12416
# _________________________________________________________________
# dropout_2 (Dropout)          (None, None, 32)          0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 84,769
# Trainable params: 84,769
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1875 samples, validate on 625 samples
# Epoch 1/10
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.6932 - acc: 0.5029 - val_loss: 0.6926 - val_acc: 0.4992
# Epoch 2/10
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.6919 - acc: 0.5216 - val_loss: 0.6912 - val_acc: 0.5504
# Epoch 3/10
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.6896 - acc: 0.5381 - val_loss: 0.6841 - val_acc: 0.6000
# Epoch 4/10
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.6273 - acc: 0.6528 - val_loss: 0.5718 - val_acc: 0.7520
# Epoch 5/10
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.5065 - acc: 0.7851 - val_loss: 0.4888 - val_acc: 0.7712
# Epoch 6/10
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.4208 - acc: 0.8432 - val_loss: 0.5129 - val_acc: 0.7568
# Epoch 7/10
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.3722 - acc: 0.8592 - val_loss: 0.5301 - val_acc: 0.7504
# Epoch 8/10
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3694 - acc: 0.8752 - val_loss: 0.5722 - val_acc: 0.7648
# Epoch 9/10
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.3071 - acc: 0.8960 - val_loss: 0.5390 - val_acc: 0.7616
# Epoch 10/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2754 - acc: 0.9131 - val_loss: 0.6238 - val_acc: 0.7600
